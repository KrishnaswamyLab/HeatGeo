# %% [markdown]
# ### Chebyshev approximation
#
# function modified from
# Code from https://github.com/sibyllema/Fast-Multiscale-Diffusion-on-Graphs
# Commit: 949ed48
# Paper: https://arxiv.org/pdf/2104.14652.pdf

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(expm_multiply)
# Out:
# ---
#
# ### expm_multiply
#
# >      expm_multiply (L, X, phi, tau, K=None, err=1e-32)

# %%
#| echo: false
#| output: asis
show_doc(compute_chebychev_coeff_all)
# Out:
# ---
#
# ### compute_chebychev_coeff_all
#
# >      compute_chebychev_coeff_all (phi, tau, K)
#
# Compute the K+1 Chebychev coefficients for our functions.

# %%
#| echo: false
#| output: asis
show_doc(reverse_bound)
# Out:
# ---
#
# ### reverse_bound
#
# >      reverse_bound (f, phi, x, tau, err)
#
# Returns the minimal K such that f(phi, x, tau, K) <= err.

# %%
#| echo: false
#| output: asis
show_doc(get_bound_bergamaschi_specific)
# Out:
# ---
#
# ### get_bound_bergamaschi_specific
#
# >      get_bound_bergamaschi_specific (phi, x, tau, K)

# %%
#| echo: false
#| output: asis
show_doc(get_bound_bergamaschi_generic)
# Out:
# ---
#
# ### get_bound_bergamaschi_generic
#
# >      get_bound_bergamaschi_generic (phi, x, tau, K)

# %%
#| echo: false
#| output: asis
show_doc(E)
# Out:
# ---
#
# ### E
#
# >      E (K, C)

# %%
#| echo: false
#| output: asis
show_doc(get_bound_eta_specific)
# Out:
# ---
#
# ### get_bound_eta_specific
#
# >      get_bound_eta_specific (phi, x, tau, K)

# %%
#| echo: false
#| output: asis
show_doc(get_bound_eta_generic)
# Out:
# ---
#
# ### get_bound_eta_generic
#
# >      get_bound_eta_generic (phi, x, tau, K)

# %%
#| echo: false
#| output: asis
show_doc(get_bound_eps_generic)
# Out:
# ---
#
# ### get_bound_eps_generic
#
# >      get_bound_eps_generic (phi, x, tau, K)

# %%
#| echo: false
#| output: asis
show_doc(g)
# Out:
# ---
#
# ### g
#
# >      g (K, C)
