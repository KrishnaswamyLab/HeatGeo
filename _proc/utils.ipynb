# %% [markdown]
# ### Utils functions

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_optimal_heat)
# Out:
# ---
#
# [source](https://github.com/guillaumehu/heatgeo/blob/main/heatgeo/utils.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_optimal_heat
#
# >      get_optimal_heat (emb_op, tau_max:float=50, n_tau:int=20)
#
# Select the optimal tau for the heat kernel.
#
# Optimal tau is found using Checbyshev approximation.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | emb_op |  |  |  |
# | tau_max | float | 50 |  |
# | n_tau | int | 20 |  |
# | **Returns** | **H: np.array (n_nodes, n_nodes)** |  | **Heat kernel with optimal tau.** |

# %%
#| echo: false
#| output: asis
show_doc(time_entropy)
# Out:
# ---
#
# [source](https://github.com/guillaumehu/heatgeo/blob/main/heatgeo/utils.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### time_entropy
#
# >      time_entropy (H)

# %%
#| echo: false
#| output: asis
show_doc(interpolate)
# Out:
# ---
#
# [source](https://github.com/guillaumehu/heatgeo/blob/main/heatgeo/utils.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### interpolate
#
# >      interpolate (x0, x1, n_steps)
