# %%
import numpy as np
from src.embedding import EmbHeatPHATE, new_HeatGeo
import matplotlib.pyplot as plt

# %%
t_phate = np.load("/network/scratch/g/guillaume.huguet/projects/metric_embeddings/data/sherlock/sub-04_early_visual_sherlock_movie_2dimension_embedding_TPHATE.npy")
data = np.load("/network/scratch/g/guillaume.huguet/projects/metric_embeddings/data/sherlock/sub-04_early_visual_sherlock_movie.npy")

# %%
# Visual the tphate embedding
plt.scatter(t_phate[:,0], t_phate[:,1], cmap="tab10")
plt.show()

# %%
data.shape
# Out:
# (1976, 307)

# %%
emb = new_HeatGeo(knn=10,order=20, tau=0.5, filter_method="mar", scale_factor=1, log_normalize=True).fit_transform(data)
plt.scatter(emb[:,0], emb[:,1], s=1)
plt.show()

# %%
mu = data.mean(axis=0)
std = data.std(axis=0)
data_n = (data - mu) / std

# %%
emb = new_HeatGeo(knn=5,order=60, tau=100, filter_method="euler", scale_factor=1, log_normalize=False).fit_transform(data_n)
plt.scatter(emb[:,0], emb[:,1], s=1)
plt.show()
